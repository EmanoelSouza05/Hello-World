# %%
print("Hello World!")
# Out:
# Hello World!

# %%
#Implementando o jogo de pedra, papel e tesoura em python

# %%
print("-----------------" * 25)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
